# %%
import pandas as pd
from functools import reduce
import matplotlib.pyplot as plt

# %%
ruta_archivo = r"\Users\Ade\src\data\2021datospanelconsumoalimentario.xlsx"
panel21_kg = pd.read_excel(ruta_archivo)
panel21_kg
# Out:
#                 Unnamed: 0      T.ESPAÑA      CATALUÑA        ARAGÓN  \
# 0      .TOTAL ALIMENTACION  7.454360e+07  1.320175e+07  2.224317e+06
# 1             T.HUEVOS KGS  9.861295e+05  1.639197e+05  3.036903e+04
# 2           T.HUEVOS UNDS.  9.861295e+05  1.639197e+05  3.036903e+04
# 3     TOTAL HUEVOS GALLINA  9.728149e+05  1.617447e+05  2.958079e+04
# 4               OTRAS AVES  1.331459e+04  2.175023e+03  7.882403e+02
# ..                     ...           ...           ...           ...
# 676   BEBIDAS REFRESCAN.SG  9.164636e+04  9.069116e+03  1.300668e+03
# 677  HARINAS Y SEMOLAS  SG  2.837211e+04  4.948462e+03  6.996445e+02
# 678     RESTO PRODUCTOS SG  3.269743e+05  5.687004e+04  9.233700e+03
# 679    ALIMENTACION FRESCA  3.149787e+07  5.543459e+06  9.989581e+05
# 680     RESTO ALIMENTACION  4.304573e+07  7.658294e+06  1.225359e+06
#
#      ILLES BALEARS  COMUNITAT VALENCIANA  REGIÓN DE MURCIA     ANDALUCÍA  \
# ...

# %%
panel21_kg.columns = ['ventas(miles €)', 'ESPAÑA', 'CATALUÑA', 'ARAGÓN', 'ILLES BALEARS',
       'COMUNITAT VALENCIANA', 'REGIÓN DE MURCIA', 'ANDALUCÍA',
       'COMUNIDAD DE MADRID', 'CASTILLA - LA MANCHA', 'EXTREMADURA',
       'CASTILLA Y LEÓN', 'GALICIA', 'PRINCIPADO DE ASTURIAS', 'CANTABRIA',
       'PAIS VASCO', 'LA RIOJA', 'C. FORAL DE NAVARRA', 'CANARIAS']

# %%
#aqui extractado kg vendidos por CCAA y por total alimentacion y especifico
panel21_kg_torti = panel21_kg[panel21_kg["ventas(miles €)"].str.contains("tortilla|.TOTAL ALIMENTACION", case=False)]
panel21_kg_torti
# Out:
#           ventas(miles €)        ESPAÑA      CATALUÑA        ARAGÓN  \
# 0     .TOTAL ALIMENTACION  7.454360e+07  1.320175e+07  2.224317e+06
# 559  TORTILLAS REFRIGERAD  8.142035e+04  1.522011e+04  3.410084e+03
# 672  TORTILLAS REFRIGE.SG  6.185241e+04  9.565226e+03  2.487315e+03
#
#      ILLES BALEARS  COMUNITAT VALENCIANA  REGIÓN DE MURCIA     ANDALUCÍA  \
# 0     1.960488e+06          7.717933e+06      2.223493e+06  1.221275e+07
# 559   1.721594e+03          6.349187e+03      1.765592e+03  1.576739e+04
# 672   1.367533e+03          4.985329e+03      1.611038e+03  1.274655e+04
#
#      COMUNIDAD DE MADRID  CASTILLA - LA MANCHA   EXTREMADURA  CASTILLA Y LEÓN  \
# 0           9.982845e+06          3.032512e+06  1.504874e+06     4.008167e+06
# 559         1.353918e+04          3.263265e+03  1.953125e+03     4.683016e+03
# 672         1.010108e+04          2.750742e+03  1.588243e+03     4.092996e+03
#
#           GALICIA  PRINCIPADO DE ASTURIAS      CANTABRIA    PAIS VASCO  \
# ...

# %%
# suma los valores individuales de los datos de los tipos de tortilla
totales_sum = panel21_kg_torti.iloc[[1, 2]].sum()
#se añade el valor obtenido al df completo
panel21_kg_tortilla = panel21_kg_torti.append(totales_sum, ignore_index=True)
panel21_kg_tortilla = pd.DataFrame (panel21_kg_tortilla)
panel21_kg_tortilla
# Out:
#                             ventas(miles €)        ESPAÑA      CATALUÑA  \
# 0                       .TOTAL ALIMENTACION  7.454360e+07  1.320175e+07
# 1                      TORTILLAS REFRIGERAD  8.142035e+04  1.522011e+04
# 2                      TORTILLAS REFRIGE.SG  6.185241e+04  9.565226e+03
# 3  TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG  1.432728e+05  2.478534e+04
#
#          ARAGÓN  ILLES BALEARS  COMUNITAT VALENCIANA  REGIÓN DE MURCIA  \
# 0  2.224317e+06   1.960488e+06          7.717933e+06      2.223493e+06
# 1  3.410084e+03   1.721594e+03          6.349187e+03      1.765592e+03
# 2  2.487315e+03   1.367533e+03          4.985329e+03      1.611038e+03
# 3  5.897399e+03   3.089126e+03          1.133452e+04      3.376630e+03
#
#       ANDALUCÍA  COMUNIDAD DE MADRID  CASTILLA - LA MANCHA   EXTREMADURA  \
# 0  1.221275e+07         9.982845e+06          3.032512e+06  1.504874e+06
# 1  1.576739e+04         1.353918e+04          3.263265e+03  1.953125e+03
# ...

# %%
#datos de españa total y tortillas
panel21_España = panel21_kg_tortilla.iloc[[0,3], 0:2]
panel21_España
# Out:
#                             ventas(miles €)        ESPAÑA
# 0                       .TOTAL ALIMENTACION  7.454360e+07
# 3  TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG  1.432728e+05

# %%
#datos de españa total y tortillas
panel21_CCAA = panel21_kg_tortilla.drop(panel21_kg_tortilla.columns[1], axis=1).iloc[[3], :]
panel21_CCAA = pd.DataFrame(panel21_CCAA)
panel21_CCAA
# Out:
#                             ventas(miles €)    CATALUÑA     ARAGÓN  \
# 3  TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG  24785.3368  5897.3986
#
#    ILLES BALEARS  COMUNITAT VALENCIANA  REGIÓN DE MURCIA   ANDALUCÍA  \
# 3     3089.12619            11334.5155        3376.63014  28513.9313
#
#    COMUNIDAD DE MADRID  CASTILLA - LA MANCHA  EXTREMADURA  CASTILLA Y LEÓN  \
# 3           23640.2594              6014.007    3541.3682        8776.0117
#
#       GALICIA  PRINCIPADO DE ASTURIAS  CANTABRIA  PAIS VASCO    LA RIOJA  \
# 3  3659.49205              2569.46837  1700.3784   8525.8415  1078.99886
#
#    C. FORAL DE NAVARRA   CANARIAS
# 3           1764.70445  5005.2866

# %%
# exporta el DataFrame 
panel21_kg.to_csv('/Users/Ade/src/data/panel21_kg.csv', index=False)
panel21_España.to_csv('/Users/Ade/src/data/panel21_España.csv', index=False)
panel21_CCAA.to_csv('/Users/Ade/src/data/panel21_CCAAA.csv', index=False)

# %%
panel21_kg_tortilla = panel21_kg_tortilla.drop([0,1, 2])
panel21_kg_tortilla
# Out:
#                             ventas(miles €)      ESPAÑA    CATALUÑA  \
# 3  TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG  143272.756  24785.3368
#
#       ARAGÓN  ILLES BALEARS  COMUNITAT VALENCIANA  REGIÓN DE MURCIA  \
# 3  5897.3986     3089.12619            11334.5155        3376.63014
#
#     ANDALUCÍA  COMUNIDAD DE MADRID  CASTILLA - LA MANCHA  EXTREMADURA  \
# 3  28513.9313           23640.2594              6014.007    3541.3682
#
#    CASTILLA Y LEÓN     GALICIA  PRINCIPADO DE ASTURIAS  CANTABRIA  PAIS VASCO  \
# 3        8776.0117  3659.49205              2569.46837  1700.3784   8525.8415
#
#      LA RIOJA  C. FORAL DE NAVARRA   CANARIAS
# 3  1078.99886           1764.70445  5005.2866

# %%
ruta_archivo = r"\Users\Ade\src\data\2021datospanelconsumoalimentario.xlsx"
panel21_canal = pd.read_excel(ruta_archivo, sheet_name=3)
panel21_canal
# Out:
#                 Unnamed: 0      T.ESPAÑA  TDA.TRADICIONAL  ECONOMATO/COOP.  \
# 0      .TOTAL ALIMENTACION  2.958661e+07     2.038888e+06    104438.395936
# 1             T.HUEVOS KGS  4.044988e+05     1.588912e+04      1156.667421
# 2           T.HUEVOS UNDS.  6.459668e+06     2.506063e+05     18160.811630
# 3     TOTAL HUEVOS GALLINA  6.294484e+06     2.478345e+05     18056.653800
# 4               OTRAS AVES  1.651841e+05     2.771879e+03       104.157830
# ..                     ...           ...              ...              ...
# 676   BEBIDAS REFRESCAN.SG  9.750246e+04     4.834646e+02        83.459870
# 677  HARINAS Y SEMOLAS  SG  1.120409e+04     4.016980e+01        17.940429
# 678     RESTO PRODUCTOS SG  1.186648e+05     3.423047e+02       158.954202
# 679    ALIMENTACION FRESCA  1.146777e+07     1.894110e+06     41093.684231
# 680     RESTO ALIMENTACION  1.811884e+07     1.447779e+05     63344.711705
#
# ...

# %%
#unificar el nombre de españa y nombrar la serie
panel21_canal.columns = ['ventas_canal', 'ESPAÑA', 'TDA.TRADICIONAL', 'ECONOMATO/COOP.',
       'HIPERMERCADOS', 'SUPER/AUTOS/G.ALM.', 'SUPER+AUTOS', 'DISCOUNTS',
       'TDA.CONGELADOS', 'HERBORISTERIA', 'FARMACIA', 'VTA.DOMICILIO',
       'PESCADERIA', 'CARNICERIA/CHARC.', 'MERCADOS/AMBULANT.',
       'MERCADOS Y PLAZAS', 'MERCADILLOS', 'LECHERIA', 'PANADERIA',
       'BAR-BODEGA', 'AUTOCONSUMO', 'COMPRA DIRECT.PRODUCTOR', 'RESTO',
       'INTERNET']

# %%
#aqui extractado kg vendidos por canal y por total alimentacion y especifico
panel21_canal_torti = panel21_canal[panel21_canal["ventas_canal"].str.contains("tortilla|.TOTAL ALIMENTACION", case=False)]
panel21_canal_torti
# Out:
#              ventas_canal        ESPAÑA  TDA.TRADICIONAL  ECONOMATO/COOP.  \
# 0     .TOTAL ALIMENTACION  2.958661e+07     2.038888e+06    104438.395936
# 559  TORTILLAS REFRIGERAD  2.459912e+04     2.939540e+01         7.254302
# 672  TORTILLAS REFRIGE.SG  1.897251e+04     2.543586e+01         7.254302
#
#      HIPERMERCADOS  SUPER/AUTOS/G.ALM.   SUPER+AUTOS     DISCOUNTS  \
# 0     3.902739e+06        1.859947e+07  1.404566e+07  4.553810e+06
# 559   2.517802e+03        2.117344e+04  1.514506e+04  6.028376e+03
# 672   1.471856e+03        1.678001e+04  1.364484e+04  3.135164e+03
#
#      TDA.CONGELADOS  HERBORISTERIA  ...  MERCADOS/AMBULANT.  \
# 0      73719.528790   92712.048581  ...       928573.399218
# 559        1.682779      55.650852  ...            0.000000
# 672        1.682779      35.823937  ...            0.000000
#
#      MERCADOS Y PLAZAS    MERCADILLOS     LECHERIA      PANADERIA  \
# 0        538304.215516  390269.190423  7537.825651  463531.699179
# ...

# %%
#dar el dato por valor unico de tortillas
totales_sum = panel21_canal_torti.iloc[[1, 2]].sum()
#se añade el valor obtenido al df completo
panel21_canal_tortilla = panel21_canal_torti.append(totales_sum, ignore_index=True)
panel21_canal_tortilla
# Out:
#                                ventas_canal        ESPAÑA  TDA.TRADICIONAL  \
# 0                       .TOTAL ALIMENTACION  2.958661e+07     2.038888e+06
# 1                      TORTILLAS REFRIGERAD  2.459912e+04     2.939540e+01
# 2                      TORTILLAS REFRIGE.SG  1.897251e+04     2.543586e+01
# 3  TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG  4.357162e+04     5.483125e+01
#
#    ECONOMATO/COOP.  HIPERMERCADOS  SUPER/AUTOS/G.ALM.   SUPER+AUTOS  \
# 0    104438.395936   3.902739e+06        1.859947e+07  1.404566e+07
# 1         7.254302   2.517802e+03        2.117344e+04  1.514506e+04
# 2         7.254302   1.471856e+03        1.678001e+04  1.364484e+04
# 3        14.508604   3.989658e+03        3.795344e+04  2.878990e+04
#
#       DISCOUNTS  TDA.CONGELADOS  HERBORISTERIA  ...  MERCADOS/AMBULANT.  \
# 0  4.553810e+06    73719.528790   92712.048581  ...       928573.399218
# 1  6.028376e+03        1.682779      55.650852  ...            0.000000
# ...

# %%
ruta_archivo = r"\Users\Ade\src\data\2021datospanelconsumoalimentario.xlsx"
panel21_demo = pd.read_excel(ruta_archivo, sheet_name=4)
panel21_demo
# Out:
#                 Unnamed: 0      T.ESPAÑA  CLASE SOCIAL ALTA Y MEDIA ALTA  \
# 0      .TOTAL ALIMENTACION  2.958661e+07                    5.311293e+06
# 1             T.HUEVOS KGS  4.044988e+05                    7.211828e+04
# 2           T.HUEVOS UNDS.  6.459668e+06                    1.151165e+06
# 3     TOTAL HUEVOS GALLINA  6.294484e+06                    1.122345e+06
# 4               OTRAS AVES  1.651841e+05                    2.882000e+04
# ..                     ...           ...                             ...
# 676   BEBIDAS REFRESCAN.SG  9.750246e+04                    1.316822e+04
# 677  HARINAS Y SEMOLAS  SG  1.120409e+04                    1.565369e+03
# 678     RESTO PRODUCTOS SG  1.186648e+05                    2.147454e+04
# 679    ALIMENTACION FRESCA  1.146777e+07                    2.136259e+06
# 680     RESTO ALIMENTACION  1.811884e+07                    3.175034e+06
#
#      CLASE SOCIAL MEDIA  CLASE SOCIAL MEDIA BAJA  CLASE SOCIAL BAJA  \
# ...

# %%
#buscar los totales de tortilla y eliminar España (npo aporta valor)
panel21_demo_torti = panel21_demo[panel21_demo["Unnamed: 0"].str.contains("tortilla", case=False)].drop(['T.ESPAÑA'], axis=1)
panel21_demo_torti
# Out:
#                Unnamed: 0  CLASE SOCIAL ALTA Y MEDIA ALTA  CLASE SOCIAL MEDIA  \
# 559  TORTILLAS REFRIGERAD                       5113.2639           8260.3306
# 672  TORTILLAS REFRIGE.SG                       3939.7969           6334.0584
#
#      CLASE SOCIAL MEDIA BAJA  CLASE SOCIAL BAJA   SIN NIÑOS  NIÑOS - 6 AÑOS  \
# 559                6725.6705          4499.8524  15975.5240       3090.7989
# 672                5122.5329          3576.1201  12055.9387       2480.3878
#
#      NIÑOS 6 A 15 AÑOS   <35 AÑOS  35 A 49 AÑOS  ...  POBLACION  > DE 500000  \
# 559          5532.7934  2217.2789     9953.9269  ...               4758.4411
# 672          4436.1821  1829.2953     7819.4510  ...               3486.0846
#
#      JOVENES INDEPENDIENTES  PAREJ.JOVENES SIN HIJOS  \
# 559              1139.81538               1859.49810
# 672               903.34896               1376.55668
#
#      PAREJ.CON HIJOS PEQUEÑOS  PAREJ.CON HIJOS EDAD MEDIA  \
# ...

# %%
totales_sum = panel21_demo_torti.iloc[[0, 1]].sum()
#se añade el valor obtenido al df completo
panel21_demo_to = panel21_demo_torti.append(totales_sum, ignore_index=True)
panel21_demo_to 

#convierto la columna Unnamed en index porque para hacer subframes me da problemas
panel21_demo_tot = panel21_demo_to.set_index('Unnamed: 0')
panel21_demo_tot
# Out:
#                                           CLASE SOCIAL ALTA Y MEDIA ALTA  \
# Unnamed: 0
# TORTILLAS REFRIGERAD                                           5113.2639
# TORTILLAS REFRIGE.SG                                           3939.7969
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG                       9053.0608
#
#                                           CLASE SOCIAL MEDIA  \
# Unnamed: 0
# TORTILLAS REFRIGERAD                               8260.3306
# TORTILLAS REFRIGE.SG                               6334.0584
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG          14594.3890
#
#                                           CLASE SOCIAL MEDIA BAJA  \
# Unnamed: 0
# TORTILLAS REFRIGERAD                                    6725.6705
# TORTILLAS REFRIGE.SG                                    5122.5329
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG               11848.2034
#
#                                           CLASE SOCIAL BAJA   SIN NIÑOS  \
# Unnamed: 0
# ...

# %%
#elimino las filas de valores individuales
panel21_demo_total = panel21_demo_tot.drop(["TORTILLAS REFRIGERAD", "TORTILLAS REFRIGE.SG" ],axis=0)

# %%
#me quedo solo con el valor total
panel21_demo_clase = panel21_demo_total.iloc[:, 0:4]
panel21_demo_clase
# Out:
#                                           CLASE SOCIAL ALTA Y MEDIA ALTA  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG                       9053.0608
#
#                                           CLASE SOCIAL MEDIA  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG           14594.389
#
#                                           CLASE SOCIAL MEDIA BAJA  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG               11848.2034
#
#                                           CLASE SOCIAL BAJA
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG          8075.9725

# %%
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt

ax = panel21_demo_clase.plot.bar(rot=0)

# Agregar título y etiquetas de los ejes
ax.set_title('Ventas de tortillas por clase social')
ax.set_xlabel('Clase social')
ax.set_ylabel('Ventas en euros')

# Mostrar el gráfico
plt.show()

import pandas as pd
import matplotlib.pyplot as plt

# %%
#Consumo // edad de los niños en el hogar
panel21_demo_ninios = panel21_demo_total.iloc[: ,4:7]
panel21_demo_ninios
# Out:
#                                            SIN NIÑOS  NIÑOS - 6 AÑOS  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG  28031.4627       5571.1867
#
#                                           NIÑOS 6 A 15 AÑOS
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG          9968.9755

# %%
#Consumo // edad del comprador
panel21_demo_comprador = panel21_demo_total.iloc[: ,7:11]
panel21_demo_comprador
# Out:
#                                            <35 AÑOS  35 A 49 AÑOS  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG  4046.5742    17773.3779
#
#                                           50 A 64 AÑOS  65 Y MAS AÑOS
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG     13265.033      8486.6399

# %%
#Consumo // nº personas en el hogar  
panel21_demo_miembros = panel21_demo_total.iloc[: ,11:17]
panel21_demo_miembros
# Out:
#                                           1 PERSONA  2 PERSONAS  3 PERSONAS  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG  9546.0214   10708.304   8983.6233
#
#                                           4 PERSONAS  5 Y MAS PERSONAS  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG  10280.3381         4053.3378
#
#                                           POBLACION < 2000 HABIT.
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG               1349.54112

# %%
#Consumo // tamaño de la poblacion de residencia 
panel21_demo_poblac = panel21_demo_total.iloc[: ,16:21]
panel21_demo_poblac
# Out:
#                                           POBLACION < 2000 HABIT.  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG               1349.54112
#
#                                           POBLACION 2000 A 10000  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG               5232.9048
#
#                                           POBLACION 10001 A 100000  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG                17135.2118
#
#                                           POBLACION  100001 A 500000  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG                  11609.4419
#
#                                           POBLACION  > DE 500000
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG               8244.5257

# %%
#Consumo // tipo unidad convivencial  
panel21_demo_tipo = panel21_demo_total.iloc[: ,21:30]
panel21_demo_tipo
# Out:
#                                           JOVENES INDEPENDIENTES  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG              2043.16434
#
#                                           PAREJ.JOVENES SIN HIJOS  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG               3236.05478
#
#                                           PAREJ.CON HIJOS PEQUEÑOS  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG                 5571.1867
#
#                                           PAREJ.CON HIJOS EDAD MEDIA  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG                   9692.9069
#
#                                           PAREJ.CON HIJOS MAYORES  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG                4170.8215
#
#                                           HOGARES MONOPARENTALES  \
# Unnamed: 0
# TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG               3468.7494
#
# ...

# %%
panel21_demo_tipo.index
# Out:
# Index(['TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG'], dtype='object', name='Unnamed: 0')

# %%
df = panel21_demo_tipo.rename(index={"TORTILLAS REFRIGERADTORTILLAS REFRIGE.SG": "2018"})
df
# Out:
#             JOVENES INDEPENDIENTES  PAREJ.JOVENES SIN HIJOS  \
# Unnamed: 0
# 2018                    2043.16434               3236.05478
#
#             PAREJ.CON HIJOS PEQUEÑOS  PAREJ.CON HIJOS EDAD MEDIA  \
# Unnamed: 0
# 2018                       5571.1867                   9692.9069
#
#             PAREJ.CON HIJOS MAYORES  HOGARES MONOPARENTALES  \
# Unnamed: 0
# 2018                      4170.8215               3468.7494
#
#             PAREJAS ADULTAS SIN HIJOS  ADULTOS INDEPENDIENTES  RETIRADOS
# Unnamed: 0
# 2018                        4524.8559              4286.72342  6577.1628

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
import plotly.graph_objects as go

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Creamos el dataframe
data = {'JOVENES INDEPENDIENTES': [2043.16434],
        'PAREJ.JOVENES SIN HIJOS': [3236.05478],
        'PAREJ.CON HIJOS PEQUEÑOS': [5571.1867],
        'PAREJ.CON HIJOS EDAD MEDIA': [9692.9069],
        'PAREJ.CON HIJOS MAYORES': [4170.8215],
        'HOGARES MONOPARENTALES': [3468.7494],
        'PAREJAS ADULTAS SIN HIJOS': [4524.8559],
        'ADULTOS INDEPENDIENTES': [4286.72342],
        'RETIRADOS': [6577.1628]}
df = pd.DataFrame(data, index=['TORTILLAS REFRIGERADAS'])

# Creamos el gráfico de barras
df.plot(kind='bar', legend=None)

# Agregamos los títulos y etiquetas a los ejes
plt.title('Ventas de tortillas refrigeradas por tipo de hogar')
plt.xlabel('Tipo de hogar')
plt.ylabel('Ventas')

# Mostramos el gráfico
plt.show()
